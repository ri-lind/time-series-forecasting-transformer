# %% [markdown]
# ####Installation

# %%
#| hide
# !pip install -Uqq nixtla
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.3 MB/s eta 0:00:00

# %% [markdown]
# ####Import TimeGPT client

# %%
from nixtla import NixtlaClient

# %% [markdown]
# ####Client Creation and Verification

# %%
nixtla_client = NixtlaClient(
    api_key = 'nixak-bgLEHOWa4jxmToIznMKaXaxtI9EUdim2Z2geIqI6EOjEmmgu2noAvxhWiMv7TL8neMzwSIuj3VIB15d1'
)
nixtla_client.validate_api_key()
# Out:
# True

# %% [markdown]
# ####Data Collection

# %%
# Additional imports
from numpy.typing import ArrayLike
import kagglehub
import pandas as pd
from sklearn.preprocessing import StandardScaler
from datetime import datetime, timedelta
from io import StringIO
import requests

def get_weather_data(city: str) -> pd.DataFrame:
    path = kagglehub.dataset_download("gucci1337/weather-of-albania-last-three-years")
    years = [2021, 2022, 2023]
    data_frames = []

    for year in years:
        file_path = f"{path}/data_weather/{city}/{city}{year}.csv"
        df = pd.read_csv(file_path)
        df = df.dropna(subset=['tavg'])  # Remove rows where 'tavg' is NaN
        data_frames.append(df)

    # Concatenate all years' data
    concatenated_data = pd.concat(data_frames, ignore_index=True)
    return concatenated_data

def get_energy_data(year: int) -> pd.DataFrame:
    """
    Downloads daily consumption data for a given year, concatenates all days into a single DataFrame,
    and performs basic preprocessing in-place (e.g., converting the target column to float).

    Parameters:
      year (int): The year for which to retrieve data.

    Returns:
      pd.DataFrame: The combined DataFrame with the target column converted to float.
    """
    all_data = []
    current_date = datetime(year, 1, 1)
    end_date = datetime(year, 12, 31)

    while current_date <= end_date:
        date_str = f"{current_date.day}.{current_date.month}.{current_date.year}"
        url = f"https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t{date_str}"
        print(f"Fetching data for {date_str} from:\n{url}")

        try:
            response = requests.get(url)
            response.raise_for_status()
            daily_df = pd.read_csv(StringIO(response.text), sep=';')
            all_data.append(daily_df)
        except Exception as e:
            print(f"Error fetching data for {date_str}: {e}")
        current_date += timedelta(days=1)

    combined_data = pd.concat(all_data, ignore_index=True)

    # Ensure the target column exists.
    target_col = "Kita Albachten (0005),Strom (S~00000936),[kWh]"
    if target_col in combined_data.columns:
        # Remove commas and convert to numeric.
        combined_data[target_col] = pd.to_numeric(
            combined_data[target_col].str.replace(',', ''), errors='coerce'
        )
    else:
        print(f"Warning: Target column '{target_col}' not found. Available columns: {combined_data.columns.tolist()}")

    return combined_data

def get_country_data(df: pd.DataFrame, country: str, start: int = 200, end: int = 1200) -> pd.DataFrame:
    """
    Returns a DataFrame containing only the data for the given country,
    with NaN values filled using linear interpolation, sorted by 'Date_reported'
    and sliced between the given indices.
    """
    # Filter rows for the given country and sort by 'Date_reported'
    df_country = df[df['Country'] == country].sort_values('Date_reported')
    # Fill NaN values in all numeric columns using linear interpolation
    df_country = df_country.interpolate(method='linear')
    # Slice the DataFrame between start and end indices
    return df_country.iloc[start:end]

def get_healthcare_data(country : str)-> pd.DataFrame:

    # Example usage:
    CSV_FILE_ABSOLUTE_PATH = "/content/WHO-COVID-19-global-daily-data.csv"
    df = pd.read_csv(CSV_FILE_ABSOLUTE_PATH)

    # Get data for Germany (rows 200 to 1200 after sorting by Date_reported).
    df = get_country_data(df, country)
    return df

# weather data
city = "lezhe"
weather_df = get_weather_data(city)

# financial data
finance_df = pd.read_csv("/content/AMZN-stock-price.csv")

# energy data
year = 2024
energy_df = get_energy_data(year)

# healthcare data
country = "Germany"
healthcare_df = get_healthcare_data(country)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download
12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t9.12.2024
# Fetching data for 10.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t10.12.2024
# Fetching data for 11.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t11.12.2024
# Fetching data for 12.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t12.12.2024
# Fetching data for 13.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t13.12.2024
# Fetching data for 14.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t14.12.2024
# Fetching data for 15.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t15.12.2024
# Fetching data for 16.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t16.12.2024
# Fetching data for 17.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t17.12.2024
# Fetching data for 18.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t18.12.2024
# Fetching data for 19.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t19.12.2024
# Fetching data for 20.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t20.12.2024
# Fetching data for 21.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t21.12.2024
# Fetching data for 22.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t22.12.2024
# Fetching data for 23.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t23.12.2024
# Fetching data for 24.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t24.12.2024
# Fetching data for 25.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t25.12.2024
# Fetching data for 26.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t26.12.2024
# Fetching data for 27.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t27.12.2024
# Fetching data for 28.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t28.12.2024
# Fetching data for 29.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t29.12.2024
# Fetching data for 30.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t30.12.2024
# Fetching data for 31.12.2024 from:
# https://www.eview.de/e1/p3Export.php?frame=StadtMS&p=0005;S~00000936;dg1;t31.12.2024
# <ipython-input-4-8c06c05a10bc>:77: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_country = df_country.interpolate(method='linear')

# %%
finance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5088 entries, 0 to 5087
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5088 non-null   object
#  1   Adj Close  5088 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 79.6+ KB

# %% [markdown]
# #### Forecasting

# %%
cols_df_name = [
    ("date", "tavg", weather_df, "weather"),
    ("Date", "Adj Close", finance_df, "finance"),
    ("Datum/Uhrzeit", "Kita Albachten (0005),Strom (S~00000936),[kWh]", energy_df, "energy"),
    ("Date_reported", "New_cases", healthcare_df, "healthcare")
]

scaler = StandardScaler()

final_preds = {}
for time_col, target_col, df, name in cols_df_name:
  df[time_col] = pd.to_datetime(df[time_col])
  date_range = pd.date_range(start=df[time_col].min(), end=df[time_col].max(), freq='D')
  if len(date_range) != len(df):
      print("Warning: Missing dates detected. Reindexing and interpolating missing target values...")
      df = df.set_index(time_col).reindex(date_range).rename_axis(time_col).reset_index()
      df[target_col] = df[target_col].interpolate(method='linear')
  if name not in final_preds.keys():
    final_preds[name] = {}
  df[target_col] = scaler.fit_transform(df[[target_col]])

  df.to_csv(f"{name}.csv")
  print(name)
  for future_context in [32, 62, 128]:
    train_data_stop = int(0.6 * df.shape[0])
    forecast_df = nixtla_client.forecast(
        df=df.iloc[:train_data_stop],
        h=future_context,
        time_col=time_col,
        target_col=target_col
    )
    actual_df = df.iloc[train_data_stop:train_data_stop + future_context]
    print(actual_df.shape)
    if future_context not in final_preds[name].keys():
      final_preds[name][future_context] = {
          "forecast" : (time_col, "TimeGPT", forecast_df),
          "actual" : (time_col, target_col, actual_df)
      }
final_preds
# Out:
# /usr/local/lib/python3.11/dist-packages/nixtla/nixtla_client.py:383: UserWarning: `df` contains the following exogenous features: ['tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres', 'tsun'], but `X_df` was not provided and they were not declared in `hist_exog_list`. They will be ignored.
#   warnings.warn(
# weather
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon, this may lead to less accurate forecasts. Please consider using a smaller horizon.
# /usr/local/lib/python3.11/dist-packages/nixtla/nixtla_client.py:383: UserWarning: `df` contains the following exogenous features: ['tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres', 'tsun'], but `X_df` was not provided and they were not declared in `hist_exog_list`. They will be ignored.
#   warnings.warn(
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon, this may lead to less accurate forecasts. Please consider using a smaller horizon.
# (32, 11)
# /usr/local/lib/python3.11/dist-packages/nixtla/nixtla_client.py:383: UserWarning: `df` contains the following exogenous features: ['tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres', 'tsun'], but `X_df` was not provided and they were not declared in `hist_exog_list`. They will be ignored.
#   warnings.warn(
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon, this may lead to less accurate forecasts. Please consider using a smaller horizon.
# (62, 11)
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon, this may lead to less accurate forecasts. Please consider using a smaller horizon.
# (128, 11)
# Warning: Missing dates detected. Reindexing and interpolating missing target values...
# finance
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon, this may lead to less accurate forecasts. Please consider using a smaller horizon.
# (32, 2)
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon, this may lead to less accurate forecasts. Please consider using a smaller horizon.
# (62, 2)
# /usr/local/lib/python3.11/dist-packages/nixtla/nixtla_client.py:383: UserWarning: `df` contains the following exogenous features: ['* Ersatzwert'], but `X_df` was not provided and they were not declared in `hist_exog_list`. They will be ignored.
#   warnings.warn(
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon, this may lead to less accurate forecasts. Please consider using a smaller horizon.
# (128, 2)
# Warning: Missing dates detected. Reindexing and interpolating missing target values...
# energy
# /usr/local/lib/python3.11/dist-packages/nixtla/nixtla_client.py:383: UserWarning: `df` contains the following exogenous features: ['* Ersatzwert'], but `X_df` was not provided and they were not declared in `hist_exog_list`. They will be ignored.
#   warnings.warn(
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon, this may lead to less accurate forecasts. Please consider using a smaller horizon.
# (32, 3)
# /usr/local/lib/python3.11/dist-packages/nixtla/nixtla_client.py:383: UserWarning: `df` contains the following exogenous features: ['* Ersatzwert'], but `X_df` was not provided and they were not declared in `hist_exog_list`. They will be ignored.
#   warnings.warn(
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon, this may lead to less accurate forecasts. Please consider using a smaller horizon.
# (62, 3)
# /usr/local/lib/python3.11/dist-packages/nixtla/nixtla_client.py:383: UserWarning: `df` contains the following exogenous features: ['Country_code', 'Country', 'WHO_region', 'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'], but `X_df` was not provided and they were not declared in `hist_exog_list`. They will be ignored.
#   warnings.warn(
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon, this may lead to less accurate forecasts. Please consider using a smaller horizon.
# (128, 3)
# healthcare
# /usr/local/lib/python3.11/dist-packages/nixtla/nixtla_client.py:383: UserWarning: `df` contains the following exogenous features: ['Country_code', 'Country', 'WHO_region', 'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'], but `X_df` was not provided and they were not declared in `hist_exog_list`. They will be ignored.
#   warnings.warn(
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon, this may lead to less accurate forecasts. Please consider using a smaller horizon.
# (32, 8)
# /usr/local/lib/python3.11/dist-packages/nixtla/nixtla_client.py:383: UserWarning: `df` contains the following exogenous features: ['Country_code', 'Country', 'WHO_region', 'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'], but `X_df` was not provided and they were not declared in `hist_exog_list`. They will be ignored.
#   warnings.warn(
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon, this may lead to less accurate forecasts. Please consider using a smaller horizon.
# (62, 8)
# (128, 8)
# {'weather': {32: {'forecast': ('date',
#     'TimeGPT',
#              date   TimeGPT
#     0  2022-10-20 -0.039256
#     1  2022-10-21 -0.025847
#     2  2022-10-22 -0.030721
#     3  2022-10-23 -0.020765
#     4  2022-10-24 -0.008102
#     5  2022-10-25 -0.020752
#     6  2022-10-26 -0.023813
#     7  2022-10-27 -0.014410
#     8  2022-10-28 -0.000365
#     9  2022-10-29  0.005011
#     10 2022-10-30  0.018648
#     11 2022-10-31  0.016133
#     12 2022-11-01  0.001303
#     13 2022-11-02 -0.003557
#     14 2022-11-03 -0.001511
#     15 2022-11-04  0.007727
#     16 2022-11-05  0.011012
#     17 2022-11-06  0.022120
#     18 2022-11-07  0.025407
#     19 2022-11-08  0.008627
#     20 2022-11-09  0.001369
#     21 2022-11-10  0.006573
#     22 2022-11-11  0.011245
#     23 2022-11-12  0.011682
#     24 2022-11-13  0.021902
#     25 2022-11-14  0.023937
#     26 2022-11-15  0.007173
#     27 2022-11-16  0.001918
#     28 2022-11-17  0.004477
#     29 2022-11-18  0.013753
#     30 2022-11-19  0.016120
#     31 2022-11-20  0.020265),
#    'actual': ('date',
#     'tavg',
#               date      tavg  tmin  tmax   prcp  snow  wdir  wspd  wpgt    pres  \
#     657 2022-10-20 -0.057392   8.1  23.8    0.0   NaN    66   6.2  20.4  1020.5
#     658 2022-10-21 -0.183030   7.3  22.9    0.0   NaN    64   5.6  16.7  1023.4
#     659 2022-10-22 -0.095083   9.4  22.6    0.0   NaN    86   5.0  11.1  1024.4
#     660 2022-10-23 -0.019700  10.6  23.3    0.0   NaN    79   4.3  11.1  1024.7
#     661 2022-10-24  0.030555   9.7  24.7    0.0   NaN    32   4.1  11.1  1023.1
#     662 2022-10-25 -0.007137   9.3  25.0    0.0   NaN    60   3.5  11.1  1020.7
#     663 2022-10-26  0.093374  10.5  24.6    0.0   NaN    72   6.0  13.0  1020.8
#     664 2022-10-27  0.156193   9.9  26.6    0.0   NaN    49   4.6  16.7  1024.9
#     665 2022-10-28  0.131065  11.0  25.1    0.0   NaN    39   5.2  14.8  1026.1
#     666 2022-10-29 -0.007137   9.2  24.8    0.0   NaN    47   5.5  16.7  1024.8
#     667 2022-10-30 -0.044828   8.1  25.4    0.0   NaN    51   6.9  16.7  1022.1
#     668 2022-10-31  0.080810   8.8  27.0    0.0   NaN    47   3.8  16.7  1021.2
#     669 2022-11-01  0.080810   9.1  26.5    0.0   NaN    79   3.4  14.8  1022.9
#     670 2022-11-02  0.030555  10.5  23.8    0.0   NaN    69   3.9  13.0  1023.0
#     671 2022-11-03 -0.069956   9.5  23.6    0.0   NaN    57   4.5  13.0  1020.5
#     672 2022-11-04 -0.170466   9.8  20.2    7.2   NaN    77   5.1  20.4  1014.8
#     673 2022-11-05 -0.095083  14.0  17.0   32.5   NaN    78   5.7  16.7  1008.1
#     674 2022-11-06 -0.183030  11.4  19.0    2.5   NaN    36   5.0  16.7  1010.9
#     675 2022-11-07 -0.308668   8.1  20.8    0.0   NaN    21   5.1  14.8  1018.7
#     676 2022-11-08 -0.270977   9.8  20.3    0.0   NaN    63   4.7  11.1  1021.1
#     677 2022-11-09 -0.384051   7.7  20.1    0.0   NaN    42   2.9  11.1  1022.3
#     678 2022-11-10 -0.434306   7.2  20.0    0.0   NaN    12   4.6  11.1  1024.2
#     679 2022-11-11 -0.195594   9.5  20.6    0.0   NaN    76   9.7  18.5  1027.8
#     680 2022-11-12 -0.245849  10.1  17.7    0.2   NaN    65  13.3  20.4  1027.2
#     681 2022-11-13 -0.258413  11.0  17.0    0.2   NaN    41   7.8  20.4  1025.7
#     682 2022-11-14 -0.245849  10.8  19.3    0.9   NaN    39   4.1  13.0  1024.1
#     683 2022-11-15 -0.321232  11.5  19.0    4.4   NaN    63   5.4  13.0  1019.6
#     684 2022-11-16 -0.346359  11.5  16.0   51.5   NaN   108   5.8  18.5  1010.6
#     685 2022-11-17 -0.132775  13.4  18.2   22.8   NaN   123   3.6  13.0  1005.0
#     686 2022-11-18 -0.183030  12.2  19.0   35.2   NaN   155   8.1  31.5  1004.7
#     687 2022-11-19 -0.195594  12.4  20.0   44.6   NaN   151   6.5  24.1  1008.9
#     688 2022-11-20 -0.107647  12.1  19.5  101.1   NaN   122  10.7  20.4  1006.8
#
#          tsun
#     657   NaN
#     658   NaN
#     659   NaN
#     660   NaN
#     661   NaN
#     662   NaN
#     663   NaN
#     664   NaN
#     665   NaN
#     666   NaN
#     667   NaN
#     668   NaN
#     669   NaN
#     670   NaN
#     671   NaN
#     672   NaN
#     673   NaN
#     674   NaN
#     675   NaN
#     676   NaN
#     677   NaN
#     678   NaN
#     679   NaN
#     680   NaN
#     681   NaN
#     682   NaN
#     683   NaN
#     684   NaN
#     685   NaN
#     686   NaN
#     687   NaN
#     688   NaN  )},
#   62: {'forecast': ('date',
#     'TimeGPT',
#              date   TimeGPT
#     0  2022-10-20 -0.039256
#     1  2022-10-21 -0.025847
#     2  2022-10-22 -0.030721
#     3  2022-10-23 -0.020765
#     4  2022-10-24 -0.008102
#     ..        ...       ...
#     57 2022-12-16  0.015959
#     58 2022-12-17  0.017738
#     59 2022-12-18  0.017352
#     60 2022-12-19  0.015581
#     61 2022-12-20  0.010245
#
#     [62 rows x 2 columns]),
#    'actual': ('date',
#     'tavg',
#               date      tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  \
#     657 2022-10-20 -0.057392   8.1  23.8   0.0   NaN    66   6.2  20.4  1020.5
#     658 2022-10-21 -0.183030   7.3  22.9   0.0   NaN    64   5.6  16.7  1023.4
#     659 2022-10-22 -0.095083   9.4  22.6   0.0   NaN    86   5.0  11.1  1024.4
#     660 2022-10-23 -0.019700  10.6  23.3   0.0   NaN    79   4.3  11.1  1024.7
#     661 2022-10-24  0.030555   9.7  24.7   0.0   NaN    32   4.1  11.1  1023.1
#     ..         ...       ...   ...   ...   ...   ...   ...   ...   ...     ...
#     714 2022-12-16 -0.233285  13.0  17.2  39.4   NaN   103   7.6  24.1  1012.2
#     715 2022-12-17 -0.233285  11.3  17.6  40.6   NaN   146   9.7  20.4  1015.7
#     716 2022-12-18 -0.572508   8.8  15.4   0.0   NaN    86  14.2  24.1  1026.3
#     717 2022-12-19 -0.936858   6.2  13.1   0.0   NaN    86  11.5  24.1  1032.3
#     718 2022-12-20 -1.163006   3.2  13.3   0.0   NaN    70   7.4  16.7  1029.8
#
#          tsun
#     657   NaN
#     658   NaN
#     659   NaN
#     660   NaN
#     661   NaN
#     ..    ...
#     714   NaN
#     715   NaN
#     716   NaN
#     717   NaN
#     718   NaN
#
#     [62 rows x 11 columns])},
#   128: {'forecast': ('date',
#     'TimeGPT',
#               date   TimeGPT
#     0   2022-10-20 -0.039256
#     1   2022-10-21 -0.025847
#     2   2022-10-22 -0.030721
#     3   2022-10-23 -0.020765
#     4   2022-10-24 -0.008102
#     ..         ...       ...
#     123 2023-02-20  0.009194
#     124 2023-02-21  0.006413
#     125 2023-02-22 -0.000044
#     126 2023-02-23  0.001490
#     127 2023-02-24  0.009510
#
#     [128 rows x 2 columns]),
#    'actual': ('date',
#     'tavg',
#               date      tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  \
#     657 2022-10-20 -0.057392   8.1  23.8   0.0   NaN    66   6.2  20.4  1020.5
#     658 2022-10-21 -0.183030   7.3  22.9   0.0   NaN    64   5.6  16.7  1023.4
#     659 2022-10-22 -0.095083   9.4  22.6   0.0   NaN    86   5.0  11.1  1024.4
#     660 2022-10-23 -0.019700  10.6  23.3   0.0   NaN    79   4.3  11.1  1024.7
#     661 2022-10-24  0.030555   9.7  24.7   0.0   NaN    32   4.1  11.1  1023.1
#     ..         ...       ...   ...   ...   ...   ...   ...   ...   ...     ...
#     780 2023-02-20 -0.735837   4.2  18.8   0.0   NaN    15   4.8  16.7  1025.1
#     781 2023-02-21 -0.760965   5.2  17.2   0.0   NaN   117   6.4  11.1  1023.0
#     782 2023-02-22 -0.760965   4.0  18.4   0.0   NaN    97   5.0  13.0  1018.4
#     783 2023-02-23 -0.748401   5.6  16.4   1.3   NaN   189   4.9  13.0  1016.9
#     784 2023-02-24 -0.673018   6.4  16.2   0.4   NaN   136   4.8  13.0  1016.8
#
#          tsun
#     657   NaN
#     658   NaN
#     659   NaN
#     660   NaN
#     661   NaN
#     ..    ...
#     780   NaN
#     781   NaN
#     782   NaN
#     783   NaN
#     784   NaN
#
#     [128 rows x 11 columns])}},
#  'finance': {32: {'forecast': ('Date',
#     'TimeGPT',
#              Date   TimeGPT
#     0  2009-07-02 -0.396560
#     1  2009-07-03 -0.393803
#     2  2009-07-04 -0.393496
#     3  2009-07-05 -0.394771
#     4  2009-07-06 -0.395911
#     5  2009-07-07 -0.396878
#     6  2009-07-08 -0.396936
#     7  2009-07-09 -0.394520
#     8  2009-07-10 -0.392593
#     9  2009-07-11 -0.392513
#     10 2009-07-12 -0.393485
#     11 2009-07-13 -0.395056
#     230 2024-08-18 01:00:00                                       -0.430576
#     231 2024-08-19 01:00:00                                       -0.683125
#     232 2024-08-20 01:00:00                                       -1.377635
#     233 2024-08-21 01:00:00                                        0.516484
#     234 2024-08-22 01:00:00                                       -0.872536
#     235 2024-08-23 01:00:00                                       -0.556850
#     236 2024-08-24 01:00:00                                       -0.114889
#     237 2024-08-25 01:00:00                                        0.516484
#     238 2024-08-26 01:00:00                                       -0.367438
#     239 2024-08-27 01:00:00                                       -0.683125
#     240 2024-08-28 01:00:00                                       -1.125086
#     241 2024-08-29 01:00:00                                       -0.178026
#     242 2024-08-30 01:00:00                                       -0.619987
#     243 2024-08-31 01:00:00                                        2.663151
#     244 2024-09-01 01:00:00                                        0.579621
#     245 2024-09-02 01:00:00                                        1.400406
#     246 2024-09-03 01:00:00                                        0.137660
#     247 2024-09-04 01:00:00                                       -0.430576
#     248 2024-09-05 01:00:00                                       -1.314497
#     249 2024-09-06 01:00:00                                       -0.556850
#     250 2024-09-07 01:00:00                                        1.905504
#
#         * Ersatzwert
#     219
#     220
#     221
#     222
#     223
#     224
#     225
#     226
#     227
#     228
#     229
#     230
#     231
#     232
#     233
#     234
#     235
#     236
#     237
#     238
#     239
#     240
#     241
#     242
#     243
#     244
#     245
#     246
#     247
#     248
#     249
#     250               )},
#   62: {'forecast': ('Datum/Uhrzeit',
#     'TimeGPT',
#              Datum/Uhrzeit   TimeGPT
#     0  2024-08-07 01:00:00 -1.246444
#     1  2024-08-08 01:00:00 -0.913058
#     2  2024-08-09 01:00:00 -1.023576
#     3  2024-08-10 01:00:00 -1.255223
#     4  2024-08-11 01:00:00 -1.492908
#     ..                 ...       ...
#     57 2024-10-03 01:00:00 -1.283514
#     58 2024-10-04 01:00:00 -1.287995
#     59 2024-10-05 01:00:00 -1.299070
#     60 2024-10-06 01:00:00 -1.351946
#     61 2024-10-07 01:00:00 -1.462171
#
#     [62 rows x 2 columns]),
#    'actual': ('Datum/Uhrzeit',
#     'Kita Albachten (0005),Strom (S~00000936),[kWh]',
#               Datum/Uhrzeit  Kita Albachten (0005),Strom (S~00000936),[kWh]  \
#     219 2024-08-07 01:00:00                                        1.400406
#     220 2024-08-08 01:00:00                                       -1.945870
#     221 2024-08-09 01:00:00                                       -1.945870
#     222 2024-08-10 01:00:00                                       -0.304301
#     223 2024-08-11 01:00:00                                       -0.178026
#     ..                  ...                                             ...
#     276 2024-10-03 01:00:00                                        0.895307
#     277 2024-10-04 01:00:00                                       -0.556850
#     278 2024-10-05 01:00:00                                        0.516484
#     279 2024-10-06 01:00:00                                       -0.556850
#     280 2024-10-07 01:00:00                                       -0.746262
#
#         * Ersatzwert
#     219
#     220
#     221
#     222
#     223
#     ..           ...
#     276
#     277
#     278
#     279
#     280
#
#     [62 rows x 3 columns])},
#   128: {'forecast': ('Datum/Uhrzeit',
#     'TimeGPT',
#               Datum/Uhrzeit   TimeGPT
#     0   2024-08-07 01:00:00 -1.246444
#     1   2024-08-08 01:00:00 -0.913058
#     2   2024-08-09 01:00:00 -1.023576
#     3   2024-08-10 01:00:00 -1.255223
#     4   2024-08-11 01:00:00 -1.492908
#     ..                  ...       ...
#     123 2024-12-08 01:00:00 -1.356278
#     124 2024-12-09 01:00:00 -1.451604
#     125 2024-12-10 01:00:00 -1.443920
#     126 2024-12-11 01:00:00 -1.316080
#     127 2024-12-12 01:00:00 -1.306105
#
#     [128 rows x 2 columns]),
#    'actual': ('Datum/Uhrzeit',
#     'Kita Albachten (0005),Strom (S~00000936),[kWh]',
#               Datum/Uhrzeit  Kita Albachten (0005),Strom (S~00000936),[kWh]  \
#     219 2024-08-07 01:00:00                                        1.400406
#     220 2024-08-08 01:00:00                                       -1.945870
#     221 2024-08-09 01:00:00                                       -1.945870
#     222 2024-08-10 01:00:00                                       -0.304301
#     223 2024-08-11 01:00:00                                       -0.178026
#     ..                  ...                                             ...
#     342 2024-12-08 01:00:00                                        0.832170
#     343 2024-12-09 01:00:00                                        0.769033
#     344 2024-12-10 01:00:00                                        0.137660
#     345 2024-12-11 01:00:00                                       -0.619987
#     346 2024-12-12 01:00:00                                        2.410602
#
#         * Ersatzwert
#     219
#     220
#     221
#     222
#     223
#     ..           ...
#     342
#     343
#     344
#     345
#     346
#
#     [128 rows x 3 columns])}},
#  'healthcare': {32: {'forecast': ('Date_reported',
#     'TimeGPT',
#        Date_reported   TimeGPT
#     0     2022-03-14  3.339178
#     1     2022-03-15  3.288432
#     2     2022-03-16  3.278436
#     3     2022-03-17  3.305450
#     4     2022-03-18  3.319968
#     5     2022-03-19  3.327783
#     6     2022-03-20  3.316639
#     7     2022-03-21  3.311920
#     8     2022-03-22  3.264295
#     9     2022-03-23  3.247568
#     10    2022-03-24  3.254067
#     11    2022-03-25  3.262929
#     12    2022-03-26  3.268537
#     13    2022-03-27  3.269151
#     14    2022-03-28  3.288028
#     15    2022-03-29  3.276128
#     16    2022-03-30  3.268066
#     17    2022-03-31  3.276753
#     18    2022-04-01  3.281884
#     19    2022-04-02  3.279819
#     20    2022-04-03  3.277691
#     21    2022-04-04  3.279139
#     22    2022-04-05  3.275082
#     23    2022-04-06  3.259975
#     24    2022-04-07  3.254652
#     25    2022-04-08  3.259174
#     26    2022-04-09  3.250393
#     27    2022-04-10  3.261420
#     28    2022-04-11  3.264275
#     29    2022-04-12  3.258185
#     30    2022-04-13  3.254315
#     31    2022-04-14  3.255806),
#    'actual': ('Date_reported',
#     'New_cases',
#            Date_reported Country_code  Country WHO_region  New_cases  \
#     192135    2022-03-14           DE  Germany        EUR   3.386408
#     192349    2022-03-15           DE  Germany        EUR   3.456104
#     192615    2022-03-16           DE  Germany        EUR   3.525799
#     192830    2022-03-17           DE  Germany        EUR   3.595495
#     193095    2022-03-18           DE  Germany        EUR   3.665191
#     193310    2022-03-19           DE  Germany        EUR   3.734887
#     193575    2022-03-20           DE  Germany        EUR   3.804583
#     193790    2022-03-21           DE  Germany        EUR   3.807222
#     194055    2022-03-22           DE  Germany        EUR   3.809862
#     194270    2022-03-23           DE  Germany        EUR   3.812501
#     192349    2022-03-15           DE  Germany        EUR   3.456104
#     192615    2022-03-16           DE  Germany        EUR   3.525799
#     192830    2022-03-17           DE  Germany        EUR   3.595495
#     193095    2022-03-18           DE  Germany        EUR   3.665191
#     ...              ...          ...      ...        ...        ...
#     205790    2022-05-10           DE  Germany        EUR   0.538831
#     206055    2022-05-11           DE  Germany        EUR   0.512923
#     206269    2022-05-12           DE  Germany        EUR   0.487015
#     206534    2022-05-13           DE  Germany        EUR   0.461107
#     206749    2022-05-14           DE  Germany        EUR   0.435199
#
#             Cumulative_cases   New_deaths  Cumulative_deaths
#     192135          17394716  1800.285714             132292
#     192349          17394716  1822.571429             132292
#     192615          17394716  1844.857143             132292
#     192830          17394716  1867.142857             132292
#     193095          17394716  1889.428571             132292
#     ...                  ...          ...                ...
#     205790          25424640   505.857143             141947
#     206055          25424640   488.285714             141947
#     206269          25424640   470.714286             141947
#     206534          25424640   453.142857             141947
#     206749          25424640   435.571429             141947
#
#     [62 rows x 8 columns])},
#   128: {'forecast': ('Date_reported',
#     'TimeGPT',
#         Date_reported   TimeGPT
#     0      2022-03-14  3.339178
#     1      2022-03-15  3.288432
#     2      2022-03-16  3.278436
#     3      2022-03-17  3.305450
#     4      2022-03-18  3.319968
#     ..            ...       ...
#     123    2022-07-15  3.267262
#     124    2022-07-16  3.267956
#     125    2022-07-17  3.271367
#     126    2022-07-18  3.280034
#     127    2022-07-19  3.269718
#
#     [128 rows x 2 columns]),
#    'actual': ('Date_reported',
#     'New_cases',
#            Date_reported Country_code  Country WHO_region  New_cases  \
#     192135    2022-03-14           DE  Germany        EUR   3.386408
#     192349    2022-03-15           DE  Germany        EUR   3.456104
#     192615    2022-03-16           DE  Germany        EUR   3.525799
#     192830    2022-03-17           DE  Germany        EUR   3.595495
#     193095    2022-03-18           DE  Germany        EUR   3.665191
#     ...              ...          ...      ...        ...        ...
#     221630    2022-07-15           DE  Germany        EUR   1.142017
#     221894    2022-07-16           DE  Germany        EUR   1.160935
#     222109    2022-07-17           DE  Germany        EUR   1.179854
#     222374    2022-07-18           DE  Germany        EUR   1.160038
#     222589    2022-07-19           DE  Germany        EUR   1.140223
#
#             Cumulative_cases   New_deaths  Cumulative_deaths
#     192135          17394716  1800.285714             132292
#     192349          17394716  1822.571429             132292
#     192615          17394716  1844.857143             132292
#     192830          17394716  1867.142857             132292
#     193095          17394716  1889.428571             132292
#     ...                  ...          ...                ...
#     221630          29129765   886.285714             145696
#     221894          29129765   923.142857             145696
#     222109          29804895   960.000000             146656
#     222374          29804895   984.142857             146656
#     222589          29804895  1008.285714             146656
#
#     [128 rows x 8 columns])}}}

# %% [markdown]
# ####Data Validation and Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score, explained_variance_score

# Iterate over each dataset and forecast horizon in final_preds.
for dataset_name, horizons in final_preds.items():
    for horizon, pred_dict in horizons.items():
        # Unpack the tuples.
        # For forecast, the tuple is: (time_col, "TimeGPT", forecast_df)
        # For actual, the tuple is: (time_col, target_col, actual_df)
        f_time_col, _, forecast_df = pred_dict["forecast"]
        a_time_col, target_col, actual_df = pred_dict["actual"]

        # Compute the error metrics.
        mse_val = mean_squared_error(actual_df[target_col], forecast_df["TimeGPT"])
        rmse_val = np.sqrt(mse_val)
        mae_val = mean_absolute_error(actual_df[target_col], forecast_df["TimeGPT"])
        mape_val = mean_absolute_percentage_error(actual_df[target_col], forecast_df["TimeGPT"])
        r2_val = r2_score(actual_df[target_col], forecast_df["TimeGPT"])
        explained_val = explained_variance_score(actual_df[target_col], forecast_df["TimeGPT"])

        print(f"{dataset_name} (Horizon {horizon}) -> RMSE: {rmse_val:.4f}, MAE: {mae_val:.4f}, MAPE: {mape_val:.4f}, R2: {r2_val:.4f}, Explained: {explained_val:.4f}")

        # Prepare the x-axis using the time column.
        try:
            x_forecast = pd.to_datetime(forecast_df[f_time_col])
        except Exception:
            x_forecast = forecast_df.index
        try:
            x_actual = pd.to_datetime(actual_df[a_time_col])
        except Exception:
            x_actual = actual_df.index

        # Create a plot of actual vs. forecast.
        plt.figure(figsize=(10, 5))
        plt.plot(x_actual, actual_df[target_col], label="Actual", marker="o")
        plt.plot(x_forecast, forecast_df["TimeGPT"], label="Forecast", marker="x")
        plt.title(f"{dataset_name.capitalize()} Forecast vs Actual (Horizon: {horizon})")
        plt.xlabel("Date")
        plt.ylabel(target_col)
        plt.legend()
        plt.grid(True)
        plt.tight_layout()

        # Save the plot to a file.
        plot_filename = f"{dataset_name}_{horizon}_forecast_plot.png"
        plt.savefig(plot_filename)
        plt.close()
# Out:
# weather (Horizon 32) -> RMSE: 0.2045, MAE: 0.1665, MAPE: 1.0480, R2: -0.7719, Explained: -0.1006
# weather (Horizon 62) -> RMSE: 0.5659, MAE: 0.4434, MAPE: 1.0368, R2: -1.3267, Explained: -0.0308
# weather (Horizon 128) -> RMSE: 0.9146, MAE: 0.7831, MAPE: 1.0222, R2: -2.5356, Explained: -0.0105
# finance (Horizon 32) -> RMSE: 0.0197, MAE: 0.0173, MAPE: 0.0442, R2: -0.0108, Explained: -0.0027
# finance (Horizon 62) -> RMSE: 0.0153, MAE: 0.0124, MAPE: 0.0317, R2: -0.0324, Explained: -0.0032
# finance (Horizon 128) -> RMSE: 0.0644, MAE: 0.0398, MAPE: 0.1443, R2: -0.3660, Explained: -0.0024
# energy (Horizon 32) -> RMSE: 1.5350, MAE: 1.2325, MAPE: 4.0135, R2: -1.1474, Explained: -0.0578
# energy (Horizon 62) -> RMSE: 1.5513, MAE: 1.3120, MAPE: 3.9580, R2: -1.8701, Explained: -0.0356
# energy (Horizon 128) -> RMSE: 1.6168, MAE: 1.3907, MAPE: 4.3966, R2: -1.9405, Explained: -0.0144
# healthcare (Horizon 32) -> RMSE: 0.7071, MAE: 0.5796, MAPE: 0.2313, R2: -0.0181, Explained: 0.0309
# healthcare (Horizon 62) -> RMSE: 1.6635, MAE: 1.3854, MAPE: 1.4727, R2: -0.9381, Explained: 0.0149
# healthcare (Horizon 128) -> RMSE: 2.3341, MAE: 2.1055, MAPE: 14.1216, R2: -2.7227, Explained: 0.0088
